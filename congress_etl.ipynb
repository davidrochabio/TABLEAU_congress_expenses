# %%
import requests
import pandas as pd
import numpy as np
import time
import itertools
import os

def expenses_cong(id_dep, years, page):

    years_lst = list(years)

    headers = {
        'accept': 'application/json',
    }

    params = (
        ('ano', years_lst),
        ('pagina', page),
        ('itens', '100'),
        ('ordem', 'ASC'),
        ('ordenarPor', 'ano'),
    )

    response = requests.get('https://dadosabertos.camara.leg.br/api/v2/deputados/' + id_dep + '/despesas',
                            headers=headers,
                            params=params)

    return response.json()


congs_df = pd.read_excel('congress_men.xls')

ids_lst = np.array(congs_df['id'])

names_lst = np.array(congs_df['nome'])

parties_lst= np.array(congs_df['siglaPartido'])

ufs_lst = np.array(congs_df['siglaUf'])

print('Requests loop initialized')
ti = time.time()

df1_lst = []

for (i, j, k, l) in zip(ids_lst, names_lst, parties_lst, ufs_lst):
    print(i, j)
    df2_lst = []
    for num in range(1, 13, 1):  # iterates thru all the pages of expense results (each page has 100 results).

        expense = expenses_cong(id_dep=str(i), years=['2019', '2020', '2021'], page=str(num))  # calls the function on a congressman.

        data = expense['dados']  # key for the data of an expense.

        df = pd.DataFrame(data)  # transforms the dict into a data frame.

        df2_lst.append(df)  # appends each page df to a list of data frames


    
    result_spending = pd.concat(df2_lst, ignore_index=True)  # concatenates the data frames(pages) into 1 df.

    result_spending['id'] = np.array([i] * len(result_spending))

    result_spending['name'] = np.array([j] * len(result_spending))

    result_spending['party'] = np.array([k] * len(result_spending))

    result_spending['state'] = np.array([l] * len(result_spending))

    df1_lst.append(result_spending)
        
all_in_one = pd.concat(df1_lst)

tf = time.time()
print('Ruquests loop finalized in',tf-ti, 'seconds')

all_in_one.to_csv(path_or_buf='/home/jovyan/work/indiv_expense/all_congs_expenses.csv')
# Out:
# Requests loop initialized
# 66179 Norma Ayub
# 66828 Fausto Pinato
# 67138 Iracema Portella
# 68720 Fábio Henrique
# 69871 Bacelar
# 72442 Felipe Carreras
# 73433 Arlindo Chinaglia
# 73441 Celso Russomanno
# 73460 Gustavo Fruet
# 73466 Rubens Bueno
# 73482 Henrique Fontana
# 73486 Pompeo de Mattos
# 73531 Ivan Valente
# 73586 Júlio Delgado
# 73604 Rui Falcão
# 73692 Osmar Terra
# 73696 Angela Amin
# 73701 Benedita da Silva
# 73772 Hermes Parcianello
# 73788 Ricardo Barros
# 73801 Renildo Calheiros
# 73808 Sérgio Brito
# 73891 Darcísio Perondi
# 73943 Perpétua Almeida
# 74043 Wellington Roberto
# 74044 Wilson Santiago
# 74052 Bosco Costa
# 74057 Alice Portugal
# 74060 Daniel Almeida
# 74075 Elcione Barbalho
# 74079 José Priante
# 74090 Átila Lins
# 74141 Josias Gomes
# 74156 Leonardo Monteiro
# 74158 Mário Heringer
# 74159 Odair Cunha
# 74160 Patrus Ananias
# 74161 Reginaldo Lopes
# 74200 Gastão Vieira
# 74212 Aníbal Gomes
# 74262 Carlos Sampaio
# 74270 Gilberto Nascimento
# 74273 Jefferson Campos
# 74283 Vicentinho
# 74299 Leônidas Cristino
# 74305 Roberto Pessoa
# 74317 Júlio Cesar
# 204518 Dr. Frederico
# 204519 Tiago Mitraud
# 204520 Junio Amaral
# 204521 Abou Anni
# 204522 Marco Bertaiolli
# 204523 Lucas Gonzalez
# 204524 Pinheirinho
# 204525 Rosana Valle
# 204526 Luiz Philippe de Orleans e Bragança
# 204527 Geninho Zuliani
# 204528 Adriana Ventura
# 204529 Policial Katia Sastre
# 204530 Rodrigo Agostinho
# 204531 Guilherme Derrite
# 204532 Vinicius Poit
# 204533 Idilvan Alencar
# 204534 Tabata Amaral
# 204535 Sâmia Bomfim
# 204536 Kim Kataguiri
# 204537 Enrico Misasi
# 204538 Paulo Bengtson
# 204539 Hercílio Coelho Diniz
# 204540 Maria Rosas
# 204541 Eduardo Bismarck
# 204542 Denis Bezerra
# 204543 Luiz Flávio Gomes
# 204544 Alexandre Frota
# 204545 Alê Silva
# 204546 Joice Hasselmann
# 204547 Léo Motta
# 204548 Heitor Freire
# 204549 AJ Albuquerque
# 204550 Júnior Mano
# 204551 Bosco Saraiva
# 204552 Eduardo Braide
# 204553 Pastor Sargento Isidório
# 204554 Abílio Santana
# 204555 José Ricardo
# 204556 Marcelo Ramos
# 204557 Sidney Leite
# 204558 Marcelo Nilo
# 204559 Zé Neto
# 204560 Adolfo Viana
# 204561 Bira do Pindaré
# 204562 Edilázio Júnior
# 204563 Josimar Maranhãozinho
# 204564 Igor Kannário
# 204565 Professora Dayane Pimentel
# 204566 Marreca Filho
# 204567 Raimundo Costa
# 204569 Delegado Pablo
# 204570 Gildenemyr
# 204571 Alex Santana
# 204572 Capitão Alberto Neto
# 204573 Otto Alencar Filho
# 204574 Junior Lourenço
# 204575 Gil Cutrim
# 204576 João Roma
# 205476 Charles Fernandes
# 205535 Patricia Ferraz
# 205548 David Miranda
# 205550 Jorge Braz
# 205863 Marcelo Brum
# 205865 Reinhold Stephanes Junior
# 206231 Ted Conti
# 207176 Bia Cavassa
# 207309 Enéias Reis
# 209189 Joseildo Ramos
# 211649 Ricardo Pericar
# 211866 Fabiano Tolentino
# 212504 Fernando Borja
# 212625 Dr. Gonçalo
# 212749 Marcão Gomes
# 213274 Ricardo Silva
# Ruquests loop finalized in 5110.236617565155 seconds

# %%
all_in_one.head()
# Out:
#       ano  mes                                        tipoDespesa  \
# 0  2019.0  1.0  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# 1  2019.0  1.0  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# 2  2019.0  1.0  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# 3  2019.0  1.0  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# 4  2019.0  1.0  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
#
#    codDocumento   tipoDocumento  codTipoDocumento dataDocumento numDocumento  \
# 0     6764297.0  Recibos/Outros               1.0    2019-01-23         2695
# 1     6760217.0     Nota Fiscal               0.0    2019-01-25    020863714
# 2     6760221.0     Nota Fiscal               0.0    2019-01-25    020863791
# 3     6760226.0     Nota Fiscal               0.0    2019-01-25    020863854
# 4     6760223.0     Nota Fiscal               0.0    2019-01-25    020863929
#
#    valorDocumento                                       urlDocumento  ...  \
# 0          120.00  https://www.camara.leg.br/cota-parlamentar/doc...  ...
# 1           36.96  https://www.camara.leg.br/cota-parlamentar/doc...  ...
# 2           35.38  https://www.camara.leg.br/cota-parlamentar/doc...  ...
# 3          204.95  https://www.camara.leg.br/cota-parlamentar/doc...  ...
# 4           35.38  https://www.camara.leg.br/cota-parlamentar/doc...  ...
#
#   cnpjCpfFornecedor valorLiquido  valorGlosa  numRessarcimento    codLote  \
# 0    39401526000119       120.00        0.00                    1568161.0
# 1    28152650000171        34.70        2.26                    1566645.0
# 2    28152650000171        34.70        0.68                    1566645.0
# 3    28152650000171       200.86        4.09                    1566645.0
# 4    28152650000171        34.70        0.68                    1566645.0
#
#    parcela       id        name party state
# 0      0.0  66179.0  Norma Ayub   DEM    ES
# 1      0.0  66179.0  Norma Ayub   DEM    ES
# 2      0.0  66179.0  Norma Ayub   DEM    ES
# 3      0.0  66179.0  Norma Ayub   DEM    ES
# 4      0.0  66179.0  Norma Ayub   DEM    ES
#
# [5 rows x 21 columns]

# %%
all_in_one.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 388592 entries, 0 to 429
# Data columns (total 21 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   ano                388592 non-null  float64
#  1   mes                388592 non-null  float64
#  2   tipoDespesa        388592 non-null  object
#  3   codDocumento       388592 non-null  float64
#  4   tipoDocumento      388592 non-null  object
#  5   codTipoDocumento   388592 non-null  float64
#  6   dataDocumento      377722 non-null  object
#  7   numDocumento       388592 non-null  object
#  8   valorDocumento     388592 non-null  float64
#  9   urlDocumento       243837 non-null  object
#  10  nomeFornecedor     388592 non-null  object
#  11  cnpjCpfFornecedor  388554 non-null  object
#  12  valorLiquido       388592 non-null  float64
#  13  valorGlosa         388592 non-null  float64
#  14  numRessarcimento   388592 non-null  object
#  15  codLote            388592 non-null  float64
#  16  parcela            388592 non-null  float64
#  17  id                 388592 non-null  float64
#  18  name               388592 non-null  object
#  19  party              388592 non-null  object
#  20  state              388592 non-null  object
# dtypes: float64(10), object(11)
# memory usage: 65.2+ MB

# %%
# !pip install openpyxl
all_in_one.to_excel('all_congs_expenses.xlsx')
# Out:
# WARNING: The directory '/home/jovyan/.cache/pip' or its parent directory is not owned or is not writable by the current user. The cache has been disabled. Check the permissions and owner of that directory. If executing pip with sudo, you may want sudo's -H flag.
# Collecting openpyxl
#   Downloading openpyxl-3.0.5-py2.py3-none-any.whl (242 kB)
#      |████████████████████████████████| 242 kB 17.6 MB/s
# Collecting jdcal
#   Downloading jdcal-1.4.1-py2.py3-none-any.whl (9.5 kB)
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.0.1.tar.gz (8.4 kB)
# Building wheels for collected packages: et-xmlfile
#   Building wheel for et-xmlfile (setup.py) ... done
#   Created wheel for et-xmlfile: filename=et_xmlfile-1.0.1-py3-none-any.whl size=8917 sha256=37c74333eb6f5131823878c3b656ce70fb3464724e403c36cd4d76d64c3fc7de
#   Stored in directory: /tmp/pip-ephem-wheel-cache-t8inmlaa/wheels/e2/bd/55/048b4fd505716c4c298f42ee02dffd9496bb6d212b266c7f31
# Successfully built et-xmlfile
# Installing collected packages: jdcal, et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.0.1 jdcal-1.4.1 openpyxl-3.0.5
# WARNING: You are using pip version 20.2.4; however, version 20.3.3 is available.
# You should consider upgrading via the '/opt/venv/bin/python -m pip install --upgrade pip' command.
